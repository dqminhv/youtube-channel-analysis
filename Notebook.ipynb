# %%
#!pip install ydata-profiling

# %%
#! pip install openpyxl

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = '/home/dqminhv/Craft_a_Story_from_a_Dataset/archive/millenniumofdata_v3_headlines.csv'

# %%
df = pd.read_csv(data_path)

# %%
#Remove the first row
df.drop(0, inplace=True)
df.reset_index()

# %%
#Remove clumn 'index'
df.drop(columns='index', inplace=True)

# %%
df = df.dropna(subset=['Description'])

# %%
df.shape
# Out:
# (808, 77)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 808 entries, 1 to 808
# Data columns (total 77 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   Description                                                                                  808 non-null    object
#  1   Real GDP of England at market prices                                                         747 non-null    object
#  2   Real GDP of England at factor cost                                                           747 non-null    object
#  3   Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders  317 non-null    object
#  4   Real UK GDP at factor cost, geographically-consistent estimate based on post-1922 borders    317 non-null    object
#  5   Index of real UK GDP at factor cost - based on changing political boundaries,                317 non-null    object
#  6   Composite estimate of English and (geographically-consistent) UK real GDP at factor cost     747 non-null    object
#  7   HP-filter of log of real composite estimate of English and UK real GDP at factor cost        747 non-null    object
#  8   Real UK gross disposable national income at market prices, constant border estimate          187 non-null    object
#  9   Real consumption                                                                             187 non-null    object
#  10  Real investment                                                                              187 non-null    object
#  11  Stockbuilding contribution                                                                   187 non-null    object
#  12  Real government consumption of goods and services                                            187 non-null    object
#  13  Export volumes                                                                               737 non-null    object
#  14  Import volumes                                                                               320 non-null    object
#  15  Nominal GDP of England at market prices                                                      747 non-null    object
#  16  Nominal UK GDP at market prices                                                              317 non-null    object
#  17  Nominal UK GDP at market prices.1                                                            317 non-null    object
#  18  Population (GB+NI)                                                                           317 non-null    object
#  19  Population (England)                                                                         808 non-null    object
#  20  Employment                                                                                   162 non-null    object
#  21  Unemployment rate                                                                            162 non-null    object
#  22  Average weekly hours worked                                                                  257 non-null    object
#  23  Capital Services, whole economy                                                              257 non-null    object
#  24  TFP growth                                                                                   256 non-null    object
#  25  Labour productivity                                                                          161 non-null    object
#  26  Labour productivity.1                                                                        161 non-null    object
#  27  Labour share, whole economy excluding rents                                                  162 non-null    object
#  28  GDP deflator at market prices                                                                747 non-null    object
#  29  Export prices                                                                                245 non-null    object
#  30  Import prices                                                                                245 non-null    object
#  31  Terms of Trade                                                                               245 non-null    object
#  32  $ Oil prices                                                                                 156 non-null    object
#  33  Earnings per head                                                                            808 non-null    object
#  34  Consumer price index                                                                         808 non-null    object
#  35  Consumer price inflation                                                                     807 non-null    object
#  36  Real consumption wages                                                                       808 non-null    object
#  37  Wholesale/producer price index                                                               356 non-null    object
#  38  Bank Rate                                                                                    323 non-null    object
#  39  Bank Rate.1                                                                                  322 non-null    object
#  40  10 year/medium-term government bond yields                                                   88 non-null     object
#  41  Consols / long-term government bond yields                                                   314 non-null    object
#  42  Mortgage rates                                                                               164 non-null    object
#  43  Corporate borrowing rate from banks                                                          95 non-null     object
#  44  Corporate bond yields                                                                        163 non-null    object
#  45  Share prices                                                                                 317 non-null    object
#  46  $/£ exchange rate                                                                            226 non-null    object
#  47  Real $/£ exchange rate                                                                       226 non-null    object
#  48  Nominal ERI                                                                                  147 non-null    object
#  49  Real ERI                                                                                     147 non-null    object
#  50  House price index                                                                            172 non-null    object
#  51  Credit                                                                                       137 non-null    object
#  52  Secured credit                                                                               137 non-null    object
#  53  Bank of England Balance sheet                                                                316 non-null    object
#  54  Bank of England Balance sheet.1                                                              316 non-null    object
#  55  Coin in circulation outside the Bank of England                                              747 non-null    object
#  56  Notes and coin in circulation                                                                184 non-null    object
#  57  Monetary base                                                                                227 non-null    object
#  58  M1                                                                                           95 non-null     object
#  59  Broad Money                                                                                  173 non-null    object
#  60  Public sector Total Managed Expenditure                                                      117 non-null    object
#  61  Public sector Total Managed Expenditure.1                                                    117 non-null    object
#  62  Public Sector Total Receipts                                                                 117 non-null    object
#  63  Public Sector Total Receipts.1                                                               117 non-null    object
#  64  Public Sector Net Lending(+)/Borrowing(-)                                                    328 non-null    object
#  65  Public Sector Net Lending(+)/Borrowing(-).1                                                  317 non-null    object
#  66  UK Public sector debt                                                                        326 non-null    object
#  67  UK Public sector debt.1                                                                      317 non-null    object
#  68  UK Public sector debt.2                                                                      317 non-null    object
#  69  Central Government Gross Debt                                                                290 non-null    object
#  70  Central Government Gross Debt.1                                                              290 non-null    object
#  71  Trade deficit                                                                                201 non-null    object
#  72  Trade deficit.1                                                                              201 non-null    object
#  73  Current account                                                                              245 non-null    object
#  74  Current account .1                                                                           245 non-null    object
#  75  Current account deficit including estimated non-monetary bullion flows                       187 non-null    object
#  76  Current account deficit including estimated non-monetary bullion flows.1                     187 non-null    object
# dtypes: object(77)
# memory usage: 492.4+ KB

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Data Profiling Report")

# %%
profile.to_widgets()
profile.to_notebook_iframe()

# %%
profile.to_file("UK millennium of macroeconomic data.html")

# %%
df['Description'] = df['Description'].astype('int64')
# Out:
# /tmp/ipykernel_1427/1092570856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Description'] = df['Description'].astype('int64')

# %%
# Create a null map using Seaborn's heatmap
plt.figure(figsize=(8, 6))  # Set the figure size (optional)

# Use df.isnull() to create a DataFrame of True/False values indicating missing values
# Use sns.heatmap to plot the null map
sns.heatmap(df.isnull(), cmap='viridis', cbar=False, yticklabels=False)

# Calculate tick positions
num_ticks = 10
min_value = min(df['Description'])
max_value = max(df['Description'])
tick_positions = np.linspace(min_value, max_value, num_ticks)

plt.yticks(tick_positions)

plt.title('Null Values Map')  # Set the title (optional)
plt.show()

# %%
int(df['Description'].iloc[0])
# Out:
# 1209

# %%
df['Description'].iloc[807]
# Out:
# '2016'
